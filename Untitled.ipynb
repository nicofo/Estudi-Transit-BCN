# %%
import json, requests
url = 'http://api.quehacenlosdiputados.net/diputados'



resp = requests.get(url)
result = json.loads(resp.text)

# %%
result[1]['normalized']['nombre']+' '+result[1]['normalized']['apellidos']+' '+result[1]['circunscripcion']
# Out:
# u'jose luis abalos meco Valencia'

# %%
result[1]
# Out:
# {u'actividad': {u'iniciativas': {u'preg_escritas': 818,
#    u'preg_orales': 23,
#    u'solicit_comparecencias': 0,
#    u'solicit_informes': 23,
#    u'solicit_nuevo_organo': 0,
#    u'total': 864},
#   u'intervenciones': {u'comision': 33,
#    u'dipuPerm': 2,
#    u'otras': 0,
#    u'pleno': 27,
#    u'total': 62},
#   u'votaciones': {u'abs': 863,
#    u'dias_no_vota': 8,
#    u'dias_vota_algo': 5,
#    u'dias_vota_todo': 175,
#    u'no': 1257,
#    u'no_vota': 147,
#    u'si': 3023,
#    u'total': 5290,
#    u'total_dias': 188}},
#  u'activo': 1,
#  u'apellidos': u'\xc1balos Meco',
#  u'cargos_congreso': [{u'alta': u'09/09/2014',
#    u'cargo': u'PO',
#    u'idOrgano': 300,
#    u'tipoOrgano': u'JP'},
#   {u'alta': u'19/12/2014',
#    u'cargo': u'V',
#    u'idOrgano': 500,
#    u'tipoOrgano': u'DP'},
#   {u'alta': u'17/05/2012',
#    u'baja': u'11/11/2014',
#    u'cargo': u'A',
#    u'idOrgano': 302,
#    u'tipoOrgano': u'C'},
#   {u'alta': u'20/10/2014',
# ...
